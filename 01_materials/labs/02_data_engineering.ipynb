# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %%
from logger import get_logger
_logs = get_logger(__name__)
_logs.info("Hello world!")
# Out:
# 2024-07-11 14:34:55,117, 530896887.py, 3, INFO, Hello world!

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")

# %%
px.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2013-12-02 00:00:00-05:00  17.425306  17.622979  17.201089  17.213892
# 2013-12-03 00:00:00-05:00  17.434676  17.687000  17.415315  17.685125
# 2013-12-04 00:00:00-05:00  17.659517  17.774750  17.513370  17.643904
# 2013-12-05 00:00:00-05:00  17.882805  17.960562  17.687941  17.734470
# 2013-12-06 00:00:00-05:00  17.668575  17.698555  17.474337  17.488388
#
#                               Volume  Dividends  Stock Splits
# Date
# 2013-12-02 00:00:00-05:00  472544800        0.0           0.0
# 2013-12-03 00:00:00-05:00  450968000        0.0           0.0
# 2013-12-04 00:00:00-05:00  377809600        0.0           0.0
# 2013-12-05 00:00:00-05:00  447580000        0.0           0.0
# 2013-12-06 00:00:00-05:00  344352400        0.0           0.0

# %%
type(px)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %%
tickers.head()
# Out:
#     ticker             Security  GICS Sector      GICS Sub-Industry  \
# 268    JCI     Johnson Controls  Industrials      Building Products
# 73     BSX    Boston Scientific  Health Care  Health Care Equipment
# 289    LIN            Linde plc    Materials       Industrial Gases
# 155    DOW             Dow Inc.    Materials    Commodity Chemicals
# 104    CVX  Chevron Corporation       Energy   Integrated Oil & Gas
#
#           Headquarters Location  Date added      CIK      Founded
# 268               Cork, Ireland       40417   833444         1885
# 73   Marlborough, Massachusetts       34754   885725         1979
# 289   Guildford, United Kingdom       33786  1707925         1879
# 155           Midland, Michigan       43556  1751788  2019 (1897)
# 104       San Ramon, California       20883    93410         1879

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Downloaded (2558, 9).
# Processing DOW
# Downloaded (1226, 9).
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# Downloaded (2558, 9).
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Downloaded (2558, 9).
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Downloaded (2558, 9).
# Processing AWK
# Downloaded (2558, 9).
# Processing MU
# Downloaded (2558, 9).
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# PEAK: No timezone found, symbol may be delisted
# No data for PEAK
# Processing BR
# Downloaded (2558, 9).
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Downloaded (1530, 9).
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Downloaded (2558, 9).
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Downloaded (2558, 9).
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Downloaded (2558, 9).
# Processing CBRE
# Downloaded (2558, 9).
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Downloaded (2558, 9).
# Processing ABNB
# Downloaded (789, 9).
# Processing MDT
# Downloaded (2558, 9).
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (118443, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((118443, 9))csv took 2.323843002319336 seconds.
# Csv file size 14.150701 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\ShwetankPC\anaconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(
# C:\Users\ShwetankPC\AppData\Local\Temp\ipykernel_81716\676544213.py:1: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
#   import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((118443, 9)) to parquet took 0.9949972629547119 seconds.
# Parquet file size 5.553297 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %%
glob(os.path.join(PRICE_DATA, "*/*.parquet"))
# Out:
# ['../../05_src/data/prices\\A\\A_2000.parquet',
#  '../../05_src/data/prices\\A\\A_2001.parquet',
#  '../../05_src/data/prices\\A\\A_2002.parquet',
#  '../../05_src/data/prices\\A\\A_2003.parquet',
#  '../../05_src/data/prices\\A\\A_2004.parquet',
#  '../../05_src/data/prices\\A\\A_2005.parquet',
#  '../../05_src/data/prices\\A\\A_2006.parquet',
#  '../../05_src/data/prices\\A\\A_2007.parquet',
#  '../../05_src/data/prices\\A\\A_2008.parquet',
#  '../../05_src/data/prices\\A\\A_2009.parquet',
#  '../../05_src/data/prices\\A\\A_2010.parquet',
#  '../../05_src/data/prices\\A\\A_2011.parquet',
#  '../../05_src/data/prices\\A\\A_2012.parquet',
#  '../../05_src/data/prices\\A\\A_2013.parquet',
#  '../../05_src/data/prices\\A\\A_2014.parquet',
#  '../../05_src/data/prices\\A\\A_2015.parquet',
#  '../../05_src/data/prices\\A\\A_2016.parquet',
#  '../../05_src/data/prices\\A\\A_2017.parquet',
#  '../../05_src/data/prices\\A\\A_2018.parquet',
#  '../../05_src/data/prices\\A\\A_2019.parquet',
#  '../../05_src/data/prices\\A\\A_2020.parquet',
#  '../../05_src/data/prices\\A\\A_2021.parquet',
#  '../../05_src/data/prices\\A\\A_2022.parquet',
#  '../../05_src/data/prices\\A\\A_2023.parquet',
#  '../../05_src/data/prices\\A\\A_2024.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2005.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2006.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2007.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2008.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2009.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2010.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2011.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2012.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2013.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2014.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2015.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2016.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2017.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2018.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2019.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2020.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2021.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2022.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2023.parquet',
#  '../../05_src/data/prices\\AAL\\AAL_2024.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2000.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2001.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2002.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2003.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2004.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2005.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2006.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2007.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2008.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2009.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2010.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2011.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2012.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2013.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2014.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2015.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2016.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2017.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2018.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2019.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2020.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2021.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2022.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2023.parquet',
#  '../../05_src/data/prices\\AAPL\\AAPL_2024.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2013.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2014.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2015.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2016.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2017.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2018.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2019.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2020.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2021.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2022.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2023.parquet',
#  '../../05_src/data/prices\\ABBV\\ABBV_2024.parquet',
#  '../../05_src/data/prices\\ABNB\\ABNB_2020.parquet',
#  '../../05_src/data/prices\\ABNB\\ABNB_2021.parquet',
#  '../../05_src/data/prices\\ABNB\\ABNB_2022.parquet',
#  '../../05_src/data/prices\\ABNB\\ABNB_2023.parquet',
#  '../../05_src/data/prices\\ABNB\\ABNB_2024.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2000.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2001.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2002.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2003.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2004.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2005.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2006.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2007.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2008.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2009.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2010.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2011.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2012.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2013.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2014.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2015.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2016.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2017.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2018.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2019.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2020.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2021.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2022.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2023.parquet',
#  '../../05_src/data/prices\\ABT\\ABT_2024.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2000.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2001.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2002.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2003.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2004.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2005.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2006.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2007.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2008.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2009.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2010.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2011.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2012.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2013.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2014.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2015.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2016.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2017.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2018.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2019.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2020.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2021.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2022.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2023.parquet',
#  '../../05_src/data/prices\\ACGL\\ACGL_2024.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2001.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2002.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2003.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2004.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2005.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2006.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2007.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2008.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2009.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2010.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2011.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2012.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2013.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2014.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2015.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2016.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2017.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2018.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2019.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2020.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2021.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2022.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2023.parquet',
#  '../../05_src/data/prices\\ACN\\ACN_2024.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2000.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2001.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2002.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2003.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2004.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2005.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2006.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2007.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2008.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2009.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2010.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2011.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2012.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2013.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2014.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2015.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2016.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2017.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2018.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2019.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2020.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2021.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2022.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2023.parquet',
#  '../../05_src/data/prices\\ADBE\\ADBE_2024.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2000.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2001.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2002.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2003.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2004.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2005.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2006.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2007.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2008.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2009.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2010.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2011.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2012.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2013.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2014.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2015.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2016.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2017.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2018.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2019.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2020.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2021.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2022.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2023.parquet',
#  '../../05_src/data/prices\\ADI\\ADI_2024.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2000.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2001.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2002.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2003.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2004.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2005.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2006.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2007.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2008.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2009.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2010.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2011.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2012.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2013.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2014.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2015.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2016.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2017.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2018.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2019.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2020.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2021.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2022.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2023.parquet',
#  '../../05_src/data/prices\\ADM\\ADM_2024.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2000.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2001.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2002.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2003.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2004.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2005.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2006.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2007.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2008.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2009.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2010.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2011.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2012.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2013.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2014.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2015.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2016.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2017.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2018.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2019.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2020.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2021.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2022.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2023.parquet',
#  '../../05_src/data/prices\\ADP\\ADP_2024.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2000.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2001.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2002.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2003.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2004.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2005.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2006.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2007.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2008.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2009.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2010.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2011.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2012.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2013.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2014.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2015.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2016.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2017.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2018.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2019.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2020.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2021.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2022.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2023.parquet',
#  '../../05_src/data/prices\\ADSK\\ADSK_2024.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2000.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2001.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2002.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2003.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2004.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2005.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2006.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2007.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2008.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2009.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2010.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2011.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2012.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2013.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2014.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2015.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2016.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2017.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2018.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2019.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2020.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2021.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2022.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2023.parquet',
#  '../../05_src/data/prices\\AEE\\AEE_2024.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2000.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2001.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2002.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2003.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2004.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2005.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2006.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2007.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2008.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2009.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2010.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2011.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2012.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2013.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2014.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2015.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2016.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2017.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2018.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2019.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2020.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2021.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2022.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2023.parquet',
#  '../../05_src/data/prices\\AEP\\AEP_2024.parquet',
#  '../../05_src/data/prices\\AES\\AES_2000.parquet',
#  '../../05_src/data/prices\\AES\\AES_2001.parquet',
#  '../../05_src/data/prices\\AES\\AES_2002.parquet',
#  '../../05_src/data/prices\\AES\\AES_2003.parquet',
#  '../../05_src/data/prices\\AES\\AES_2004.parquet',
#  '../../05_src/data/prices\\AES\\AES_2005.parquet',
#  '../../05_src/data/prices\\AES\\AES_2006.parquet',
#  '../../05_src/data/prices\\AES\\AES_2007.parquet',
#  '../../05_src/data/prices\\AES\\AES_2008.parquet',
#  '../../05_src/data/prices\\AES\\AES_2009.parquet',
#  '../../05_src/data/prices\\AES\\AES_2010.parquet',
#  '../../05_src/data/prices\\AES\\AES_2011.parquet',
#  '../../05_src/data/prices\\AES\\AES_2012.parquet',
#  '../../05_src/data/prices\\AES\\AES_2013.parquet',
#  '../../05_src/data/prices\\AES\\AES_2014.parquet',
#  '../../05_src/data/prices\\AES\\AES_2015.parquet',
#  '../../05_src/data/prices\\AES\\AES_2016.parquet',
#  '../../05_src/data/prices\\AES\\AES_2017.parquet',
#  '../../05_src/data/prices\\AES\\AES_2018.parquet',
#  '../../05_src/data/prices\\AES\\AES_2019.parquet',
#  '../../05_src/data/prices\\AES\\AES_2020.parquet',
#  '../../05_src/data/prices\\AES\\AES_2021.parquet',
#  '../../05_src/data/prices\\AES\\AES_2022.parquet',
#  '../../05_src/data/prices\\AES\\AES_2023.parquet',
#  '../../05_src/data/prices\\AES\\AES_2024.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2000.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2001.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2002.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2003.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2004.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2005.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2006.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2007.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2008.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2009.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2010.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2011.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2012.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2013.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2014.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2015.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2016.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2017.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2018.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2019.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2020.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2021.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2022.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2023.parquet',
#  '../../05_src/data/prices\\AFL\\AFL_2024.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2000.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2001.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2002.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2003.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2004.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2005.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2006.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2007.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2008.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2009.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2010.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2011.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2012.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2013.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2014.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2015.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2016.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2017.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2018.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2019.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2020.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2021.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2022.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2023.parquet',
#  '../../05_src/data/prices\\AIG\\AIG_2024.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2004.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2005.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2006.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2007.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2008.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2009.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2010.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2011.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2012.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2013.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2014.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2015.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2016.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2017.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2018.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2019.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2020.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2021.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2022.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2023.parquet',
#  '../../05_src/data/prices\\AIZ\\AIZ_2024.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2000.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2001.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2002.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2003.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2004.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2005.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2006.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2007.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2008.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2009.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2010.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2011.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2012.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2013.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2014.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2015.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2016.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2017.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2018.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2019.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2020.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2021.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2022.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2023.parquet',
#  '../../05_src/data/prices\\AJG\\AJG_2024.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2000.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2001.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2002.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2003.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2004.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2005.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2006.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2007.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2008.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2009.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2010.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2011.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2012.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2013.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2014.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2015.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2016.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2017.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2018.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2019.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2020.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2021.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2022.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2023.parquet',
#  '../../05_src/data/prices\\AKAM\\AKAM_2024.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2000.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2001.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2002.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2003.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2004.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2005.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2006.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2007.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2008.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2009.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2010.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2011.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2012.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2013.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2014.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2015.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2016.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2017.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2018.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2019.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2020.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2021.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2022.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2023.parquet',
#  '../../05_src/data/prices\\ALB\\ALB_2024.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2001.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2002.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2003.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2004.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2005.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2006.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2007.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2008.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2009.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2010.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2011.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2012.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2013.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2014.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2015.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2016.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2017.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2018.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2019.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2020.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2021.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2022.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2023.parquet',
#  '../../05_src/data/prices\\ALGN\\ALGN_2024.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2000.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2001.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2002.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2003.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2004.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2005.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2006.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2007.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2008.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2009.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2010.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2011.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2012.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2013.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2014.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2015.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2016.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2017.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2018.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2019.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2020.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2021.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2022.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2023.parquet',
#  '../../05_src/data/prices\\ALL\\ALL_2024.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2013.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2014.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2015.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2016.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2017.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2018.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2019.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2020.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2021.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2022.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2023.parquet',
#  '../../05_src/data/prices\\ALLE\\ALLE_2024.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2000.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2001.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2002.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2003.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2004.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2005.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2006.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2007.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2008.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2009.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2010.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2011.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2012.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2013.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2014.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2015.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2016.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2017.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2018.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2019.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2020.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2021.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2022.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2023.parquet',
#  '../../05_src/data/prices\\AMAT\\AMAT_2024.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2012.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2013.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2014.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2015.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2016.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2017.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2018.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2019.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2020.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2021.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2022.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2023.parquet',
#  '../../05_src/data/prices\\AMCR\\AMCR_2024.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2000.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2001.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2002.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2003.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2004.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2005.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2006.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2007.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2008.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2009.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2010.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2011.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2012.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2013.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2014.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2015.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2016.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2017.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2018.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2019.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2020.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2021.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2022.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2023.parquet',
#  '../../05_src/data/prices\\AMD\\AMD_2024.parquet',
#  '../../05_src/data/prices\\AME\\AME_2000.parquet',
#  '../../05_src/data/prices\\AME\\AME_2001.parquet',
#  '../../05_src/data/prices\\AME\\AME_2002.parquet',
#  '../../05_src/data/prices\\AME\\AME_2003.parquet',
#  '../../05_src/data/prices\\AME\\AME_2004.parquet',
#  '../../05_src/data/prices\\AME\\AME_2005.parquet',
#  '../../05_src/data/prices\\AME\\AME_2006.parquet',
#  '../../05_src/data/prices\\AME\\AME_2007.parquet',
#  '../../05_src/data/prices\\AME\\AME_2008.parquet',
#  '../../05_src/data/prices\\AME\\AME_2009.parquet',
#  '../../05_src/data/prices\\AME\\AME_2010.parquet',
#  '../../05_src/data/prices\\AME\\AME_2011.parquet',
#  '../../05_src/data/prices\\AME\\AME_2012.parquet',
#  '../../05_src/data/prices\\AME\\AME_2013.parquet',
#  '../../05_src/data/prices\\AME\\AME_2014.parquet',
#  '../../05_src/data/prices\\AME\\AME_2015.parquet',
#  '../../05_src/data/prices\\AME\\AME_2016.parquet',
#  '../../05_src/data/prices\\AME\\AME_2017.parquet',
#  '../../05_src/data/prices\\AME\\AME_2018.parquet',
#  '../../05_src/data/prices\\AME\\AME_2019.parquet',
#  '../../05_src/data/prices\\AME\\AME_2020.parquet',
#  '../../05_src/data/prices\\AME\\AME_2021.parquet',
#  '../../05_src/data/prices\\AME\\AME_2022.parquet',
#  '../../05_src/data/prices\\AME\\AME_2023.parquet',
#  '../../05_src/data/prices\\AME\\AME_2024.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2000.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2001.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2002.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2003.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2004.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2005.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2006.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2007.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2008.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2009.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2010.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2011.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2012.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2013.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2014.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2015.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2016.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2017.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2018.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2019.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2020.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2021.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2022.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2023.parquet',
#  '../../05_src/data/prices\\AMGN\\AMGN_2024.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2005.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2006.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2007.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2008.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2009.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2010.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2011.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2012.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2013.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2014.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2015.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2016.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2017.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2018.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2019.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2020.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2021.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2022.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2023.parquet',
#  '../../05_src/data/prices\\AMP\\AMP_2024.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2000.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2001.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2002.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2003.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2004.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2005.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2006.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2007.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2008.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2009.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2010.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2011.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2012.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2013.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2014.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2015.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2016.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2017.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2018.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2019.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2020.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2021.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2022.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2023.parquet',
#  '../../05_src/data/prices\\AMT\\AMT_2024.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2000.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2001.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2002.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2003.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2004.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2005.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2006.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2007.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2008.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2009.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2010.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2011.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2012.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2013.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2014.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2015.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2016.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2017.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2018.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2019.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2020.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2021.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2022.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2023.parquet',
#  '../../05_src/data/prices\\AMZN\\AMZN_2024.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2014.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2015.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2016.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2017.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2018.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2019.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2020.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2021.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2022.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2023.parquet',
#  '../../05_src/data/prices\\ANET\\ANET_2024.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2000.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2001.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2002.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2003.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2004.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2005.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2006.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2007.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2008.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2009.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2010.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2011.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2012.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2013.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2014.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2015.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2016.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2017.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2018.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2019.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2020.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2021.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2022.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2023.parquet',
#  '../../05_src/data/prices\\ANSS\\ANSS_2024.parquet',
#  '../../05_src/data/prices\\AON\\AON_2000.parquet',
#  '../../05_src/data/prices\\AON\\AON_2001.parquet',
#  '../../05_src/data/prices\\AON\\AON_2002.parquet',
#  '../../05_src/data/prices\\AON\\AON_2003.parquet',
#  '../../05_src/data/prices\\AON\\AON_2004.parquet',
#  '../../05_src/data/prices\\AON\\AON_2005.parquet',
#  '../../05_src/data/prices\\AON\\AON_2006.parquet',
#  '../../05_src/data/prices\\AON\\AON_2007.parquet',
#  '../../05_src/data/prices\\AON\\AON_2008.parquet',
#  '../../05_src/data/prices\\AON\\AON_2009.parquet',
#  '../../05_src/data/prices\\AON\\AON_2010.parquet',
#  '../../05_src/data/prices\\AON\\AON_2011.parquet',
#  '../../05_src/data/prices\\AON\\AON_2012.parquet',
#  '../../05_src/data/prices\\AON\\AON_2013.parquet',
#  '../../05_src/data/prices\\AON\\AON_2014.parquet',
#  '../../05_src/data/prices\\AON\\AON_2015.parquet',
#  '../../05_src/data/prices\\AON\\AON_2016.parquet',
#  '../../05_src/data/prices\\AON\\AON_2017.parquet',
#  '../../05_src/data/prices\\AON\\AON_2018.parquet',
#  '../../05_src/data/prices\\AON\\AON_2019.parquet',
#  '../../05_src/data/prices\\AON\\AON_2020.parquet',
#  '../../05_src/data/prices\\AON\\AON_2021.parquet',
#  '../../05_src/data/prices\\AON\\AON_2022.parquet',
#  '../../05_src/data/prices\\AON\\AON_2023.parquet',
#  '../../05_src/data/prices\\AON\\AON_2024.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2000.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2001.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2002.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2003.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2004.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2005.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2006.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2007.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2008.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2009.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2010.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2011.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2012.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2013.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2014.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2015.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2016.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2017.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2018.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2019.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2020.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2021.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2022.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2023.parquet',
#  '../../05_src/data/prices\\AOS\\AOS_2024.parquet',
#  '../../05_src/data/prices\\APA\\APA_2000.parquet',
#  '../../05_src/data/prices\\APA\\APA_2001.parquet',
#  '../../05_src/data/prices\\APA\\APA_2002.parquet',
#  '../../05_src/data/prices\\APA\\APA_2003.parquet',
#  '../../05_src/data/prices\\APA\\APA_2004.parquet',
#  '../../05_src/data/prices\\APA\\APA_2005.parquet',
#  '../../05_src/data/prices\\APA\\APA_2006.parquet',
#  '../../05_src/data/prices\\APA\\APA_2007.parquet',
#  '../../05_src/data/prices\\APA\\APA_2008.parquet',
#  '../../05_src/data/prices\\APA\\APA_2009.parquet',
#  '../../05_src/data/prices\\APA\\APA_2010.parquet',
#  '../../05_src/data/prices\\APA\\APA_2011.parquet',
#  '../../05_src/data/prices\\APA\\APA_2012.parquet',
#  '../../05_src/data/prices\\APA\\APA_2013.parquet',
#  '../../05_src/data/prices\\APA\\APA_2014.parquet',
#  '../../05_src/data/prices\\APA\\APA_2015.parquet',
#  '../../05_src/data/prices\\APA\\APA_2016.parquet',
#  '../../05_src/data/prices\\APA\\APA_2017.parquet',
#  '../../05_src/data/prices\\APA\\APA_2018.parquet',
#  '../../05_src/data/prices\\APA\\APA_2019.parquet',
#  '../../05_src/data/prices\\APA\\APA_2020.parquet',
#  '../../05_src/data/prices\\APA\\APA_2021.parquet',
#  '../../05_src/data/prices\\APA\\APA_2022.parquet',
#  '../../05_src/data/prices\\APA\\APA_2023.parquet',
#  '../../05_src/data/prices\\APA\\APA_2024.parquet',
#  '../../05_src/data/prices\\APD\\APD_2000.parquet',
#  '../../05_src/data/prices\\APD\\APD_2001.parquet',
#  '../../05_src/data/prices\\APD\\APD_2002.parquet',
#  '../../05_src/data/prices\\APD\\APD_2003.parquet',
#  '../../05_src/data/prices\\APD\\APD_2004.parquet',
#  '../../05_src/data/prices\\APD\\APD_2005.parquet',
#  '../../05_src/data/prices\\APD\\APD_2006.parquet',
#  '../../05_src/data/prices\\APD\\APD_2007.parquet',
#  '../../05_src/data/prices\\APD\\APD_2008.parquet',
#  '../../05_src/data/prices\\APD\\APD_2009.parquet',
#  '../../05_src/data/prices\\APD\\APD_2010.parquet',
#  '../../05_src/data/prices\\APD\\APD_2011.parquet',
#  '../../05_src/data/prices\\APD\\APD_2012.parquet',
#  '../../05_src/data/prices\\APD\\APD_2013.parquet',
#  '../../05_src/data/prices\\APD\\APD_2014.parquet',
#  '../../05_src/data/prices\\APD\\APD_2015.parquet',
#  '../../05_src/data/prices\\APD\\APD_2016.parquet',
#  '../../05_src/data/prices\\APD\\APD_2017.parquet',
#  '../../05_src/data/prices\\APD\\APD_2018.parquet',
#  '../../05_src/data/prices\\APD\\APD_2019.parquet',
#  '../../05_src/data/prices\\APD\\APD_2020.parquet',
#  '../../05_src/data/prices\\APD\\APD_2021.parquet',
#  '../../05_src/data/prices\\APD\\APD_2022.parquet',
#  '../../05_src/data/prices\\APD\\APD_2023.parquet',
#  '../../05_src/data/prices\\APD\\APD_2024.parquet',
#  '../../05_src/data/prices\\APH\\APH_2000.parquet',
#  '../../05_src/data/prices\\APH\\APH_2001.parquet',
#  '../../05_src/data/prices\\APH\\APH_2002.parquet',
#  '../../05_src/data/prices\\APH\\APH_2003.parquet',
#  '../../05_src/data/prices\\APH\\APH_2004.parquet',
#  '../../05_src/data/prices\\APH\\APH_2005.parquet',
#  '../../05_src/data/prices\\APH\\APH_2006.parquet',
#  '../../05_src/data/prices\\APH\\APH_2007.parquet',
#  '../../05_src/data/prices\\APH\\APH_2008.parquet',
#  '../../05_src/data/prices\\APH\\APH_2009.parquet',
#  '../../05_src/data/prices\\APH\\APH_2010.parquet',
#  '../../05_src/data/prices\\APH\\APH_2011.parquet',
#  '../../05_src/data/prices\\APH\\APH_2012.parquet',
#  '../../05_src/data/prices\\APH\\APH_2013.parquet',
#  '../../05_src/data/prices\\APH\\APH_2014.parquet',
#  '../../05_src/data/prices\\APH\\APH_2015.parquet',
#  '../../05_src/data/prices\\APH\\APH_2016.parquet',
#  '../../05_src/data/prices\\APH\\APH_2017.parquet',
#  '../../05_src/data/prices\\APH\\APH_2018.parquet',
#  '../../05_src/data/prices\\APH\\APH_2019.parquet',
#  '../../05_src/data/prices\\APH\\APH_2020.parquet',
#  '../../05_src/data/prices\\APH\\APH_2021.parquet',
#  '../../05_src/data/prices\\APH\\APH_2022.parquet',
#  '../../05_src/data/prices\\APH\\APH_2023.parquet',
#  '../../05_src/data/prices\\APH\\APH_2024.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2011.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2012.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2013.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2014.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2015.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2016.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2017.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2018.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2019.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2020.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2021.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2022.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2023.parquet',
#  '../../05_src/data/prices\\APTV\\APTV_2024.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2000.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2001.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2002.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2003.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2004.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2005.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2006.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2007.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2008.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2009.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2010.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2011.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2012.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2013.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2014.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2015.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2016.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2017.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2018.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2019.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2020.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2021.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2022.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2023.parquet',
#  '../../05_src/data/prices\\ARE\\ARE_2024.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2000.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2001.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2002.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2003.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2004.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2005.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2006.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2007.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2008.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2009.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2010.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2011.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2012.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2013.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2014.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2015.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2016.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2017.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2018.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2019.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2020.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2021.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2022.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2023.parquet',
#  '../../05_src/data/prices\\ATO\\ATO_2024.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2000.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2001.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2002.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2003.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2004.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2005.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2006.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2007.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2008.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2009.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2010.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2011.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2012.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2013.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2014.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2015.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2016.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2017.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2018.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2019.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2020.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2021.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2022.parquet',
#  '../../05_src/data/prices\\AVB\\AVB_2023.parquet',
#  ...]

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\ShwetankPC\AppData\Local\Temp\ipykernel_81716\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %%
dd_rets.head()
# Out:
#                             Date       Open       High        Low      Close  \
# ticker
# A      2013-12-02 00:00:00-05:00  34.931005  35.061659  34.695823  34.761150
# A      2013-12-03 00:00:00-05:00  34.571692  34.735014  34.336510  34.578224
# A      2013-12-04 00:00:00-05:00  34.519436  35.166188  34.441044  35.002865
# A      2013-12-05 00:00:00-05:00  34.852615  35.146592  34.702361  34.950607
# A      2013-12-06 00:00:00-05:00  35.120452  35.884789  35.120452  35.819462
#
#          Volume  Dividends  Stock Splits  year  Close_lag_1   returns  \
# ticker
# A       2039962        0.0           0.0  2013          NaN       NaN
# A       3462706        0.0           0.0  2013    34.761150 -0.005262
# A       3377288        0.0           0.0  2013    34.578224  0.012281
# A       2530939        0.0           0.0  2013    35.002865 -0.001493
# A       4268513        0.0           0.0  2013    34.950607  0.024859
#
#         positive_return
# ticker
# A                     0
# A                     0
# A                     1
# A                     0
# A                     1

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=49
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int32
# ABNB                                         ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# YUM                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.931005   35.061659   34.695823
# A      2013-12-03 00:00:00-05:00   34.571692   34.735014   34.336510
# A      2013-12-04 00:00:00-05:00   34.519436   35.166188   34.441044
# A      2013-12-05 00:00:00-05:00   34.852615   35.146592   34.702361
# A      2013-12-06 00:00:00-05:00   35.120452   35.884789   35.120452
# ...                          ...         ...         ...         ...
# YUM    2024-01-25 00:00:00-05:00  128.551783  129.027053  127.274475
# YUM    2024-01-26 00:00:00-05:00  128.640891  129.403315  127.403198
# YUM    2024-01-29 00:00:00-05:00  127.828973  129.264694  127.026935
# YUM    2024-01-30 00:00:00-05:00  129.076565  129.928098  128.304245
# YUM    2024-01-31 00:00:00-05:00  130.155828  130.680609  127.987387
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.761150  2039962        0.0           0.0  2013          NaN
# A        34.578224  3462706        0.0           0.0  2013    34.761150
# A        35.002865  3377288        0.0           0.0  2013    34.578224
# A        34.950607  2530939        0.0           0.0  2013    35.002865
# A        35.819462  4268513        0.0           0.0  2013    34.950607
# ...            ...      ...        ...           ...   ...          ...
# YUM     128.937943  1871700        0.0           0.0  2024   128.165619
# YUM     127.819061  1157000        0.0           0.0  2024   128.937943
# YUM     129.264694  1482100        0.0           0.0  2024   127.819061
# YUM     129.334000  1421500        0.0           0.0  2024   129.264694
# YUM     128.215134  2154200        0.0           0.0  2024   129.334000
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012281                1
# A      -0.001493                0
# A       0.024859                1
# ...          ...              ...
# YUM     0.006026                1
# YUM    -0.008678                0
# YUM     0.011310                1
# YUM     0.000536                1
# YUM    -0.008651                0
#
# [118443 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-07-11 19:03:10,378, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-07-11 19:03:10,378, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-07-11 19:03:10,380, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-07-11 19:03:10,380, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-07-11 19:03:10,391, data_manager.py, 58, INFO, Processing all tickers
# 2024-07-11 19:03:10,391, data_manager.py, 58, INFO, Processing all tickers
# 2024-07-11 19:03:10,395, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-07-11 19:03:10,395, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-07-11 19:03:10,397, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:10,397, data_manager.py, 108, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:10,541, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-07-11 19:03:10,541, data_manager.py, 82, INFO, Saving data for MMM by year
# 2024-07-11 19:03:11,867, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-07-11 19:03:11,867, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-07-11 19:03:11,869, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:11,869, data_manager.py, 108, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:12,021, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-07-11 19:03:12,021, data_manager.py, 82, INFO, Saving data for AOS by year
# 2024-07-11 19:03:13,312, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-07-11 19:03:13,312, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-07-11 19:03:13,315, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:13,315, data_manager.py, 108, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:13,457, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-07-11 19:03:13,457, data_manager.py, 82, INFO, Saving data for ABT by year
# 2024-07-11 19:03:14,716, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-07-11 19:03:14,716, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-07-11 19:03:14,718, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:14,718, data_manager.py, 108, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:14,770, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-07-11 19:03:14,770, data_manager.py, 82, INFO, Saving data for ABBV by year
# 2024-07-11 19:03:15,377, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-07-11 19:03:15,377, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-07-11 19:03:15,379, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:15,379, data_manager.py, 108, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:15,467, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-07-11 19:03:15,467, data_manager.py, 82, INFO, Saving data for ACN by year
# 2024-07-11 19:03:17,148, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-07-11 19:03:17,148, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-07-11 19:03:17,151, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:17,151, data_manager.py, 108, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:17,293, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-07-11 19:03:17,293, data_manager.py, 82, INFO, Saving data for ADBE by year
# 2024-07-11 19:03:18,576, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-07-11 19:03:18,576, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-07-11 19:03:18,577, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:18,577, data_manager.py, 108, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:18,675, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-07-11 19:03:18,675, data_manager.py, 82, INFO, Saving data for AMD by year
# 2024-07-11 19:03:20,001, data_manager.py, 73, INFO, Processing ticker AES
# 2024-07-11 19:03:20,001, data_manager.py, 73, INFO, Processing ticker AES
# 2024-07-11 19:03:20,003, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:20,003, data_manager.py, 108, INFO, Getting stock price data for AES from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:20,117, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-07-11 19:03:20,117, data_manager.py, 82, INFO, Saving data for AES by year
# 2024-07-11 19:03:21,390, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-07-11 19:03:21,390, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-07-11 19:03:21,392, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:21,392, data_manager.py, 108, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:21,514, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-07-11 19:03:21,514, data_manager.py, 82, INFO, Saving data for AFL by year
# 2024-07-11 19:03:22,858, data_manager.py, 73, INFO, Processing ticker A
# 2024-07-11 19:03:22,858, data_manager.py, 73, INFO, Processing ticker A
# 2024-07-11 19:03:22,860, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:22,860, data_manager.py, 108, INFO, Getting stock price data for A from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:22,983, data_manager.py, 82, INFO, Saving data for A by year
# 2024-07-11 19:03:22,983, data_manager.py, 82, INFO, Saving data for A by year
# 2024-07-11 19:03:24,242, data_manager.py, 73, INFO, Processing ticker APD
# 2024-07-11 19:03:24,242, data_manager.py, 73, INFO, Processing ticker APD
# 2024-07-11 19:03:24,244, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:24,244, data_manager.py, 108, INFO, Getting stock price data for APD from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:24,359, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-07-11 19:03:24,359, data_manager.py, 82, INFO, Saving data for APD by year
# 2024-07-11 19:03:25,616, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-07-11 19:03:25,616, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-07-11 19:03:25,617, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:25,617, data_manager.py, 108, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:25,711, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-07-11 19:03:25,711, data_manager.py, 82, INFO, Saving data for ABNB by year
# 2024-07-11 19:03:25,981, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-07-11 19:03:25,981, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-07-11 19:03:25,984, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:25,984, data_manager.py, 108, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:26,168, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-07-11 19:03:26,168, data_manager.py, 82, INFO, Saving data for AKAM by year
# 2024-07-11 19:03:27,397, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-07-11 19:03:27,397, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-07-11 19:03:27,398, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:27,398, data_manager.py, 108, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:27,748, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-07-11 19:03:27,748, data_manager.py, 82, INFO, Saving data for ALB by year
# 2024-07-11 19:03:29,118, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-07-11 19:03:29,118, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-07-11 19:03:29,119, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:29,119, data_manager.py, 108, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:29,411, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-07-11 19:03:29,411, data_manager.py, 82, INFO, Saving data for ARE by year
# 2024-07-11 19:03:30,600, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-07-11 19:03:30,600, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-07-11 19:03:30,601, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:30,601, data_manager.py, 108, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:30,775, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-07-11 19:03:30,775, data_manager.py, 82, INFO, Saving data for ALGN by year
# 2024-07-11 19:03:32,018, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-07-11 19:03:32,018, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-07-11 19:03:32,020, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:32,020, data_manager.py, 108, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:32,183, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-07-11 19:03:32,183, data_manager.py, 82, INFO, Saving data for ALLE by year
# 2024-07-11 19:03:32,798, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-07-11 19:03:32,798, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-07-11 19:03:32,800, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:32,800, data_manager.py, 108, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:33,087, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-07-11 19:03:33,087, data_manager.py, 82, INFO, Saving data for LNT by year
# 2024-07-11 19:03:34,565, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-07-11 19:03:34,565, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-07-11 19:03:34,566, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:34,566, data_manager.py, 108, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:35,053, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-07-11 19:03:35,053, data_manager.py, 82, INFO, Saving data for ALL by year
# 2024-07-11 19:03:36,332, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-07-11 19:03:36,332, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-07-11 19:03:36,334, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:36,334, data_manager.py, 108, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:36,610, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-07-11 19:03:36,610, data_manager.py, 82, INFO, Saving data for GOOGL by year
# 2024-07-11 19:03:37,763, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-07-11 19:03:37,763, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-07-11 19:03:37,764, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:37,764, data_manager.py, 108, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:38,040, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-07-11 19:03:38,040, data_manager.py, 82, INFO, Saving data for GOOG by year
# 2024-07-11 19:03:39,184, data_manager.py, 73, INFO, Processing ticker MO
# 2024-07-11 19:03:39,184, data_manager.py, 73, INFO, Processing ticker MO
# 2024-07-11 19:03:39,186, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:39,186, data_manager.py, 108, INFO, Getting stock price data for MO from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:39,518, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-07-11 19:03:39,518, data_manager.py, 82, INFO, Saving data for MO by year
# 2024-07-11 19:03:40,853, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-07-11 19:03:40,853, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-07-11 19:03:40,855, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:40,855, data_manager.py, 108, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:41,107, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-07-11 19:03:41,107, data_manager.py, 82, INFO, Saving data for AMZN by year
# 2024-07-11 19:03:42,393, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-07-11 19:03:42,393, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-07-11 19:03:42,395, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:42,395, data_manager.py, 108, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:42,568, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-07-11 19:03:42,568, data_manager.py, 82, INFO, Saving data for AMCR by year
# 2024-07-11 19:03:43,283, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-07-11 19:03:43,283, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-07-11 19:03:43,284, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:43,284, data_manager.py, 108, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:43,579, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-07-11 19:03:43,579, data_manager.py, 82, INFO, Saving data for AEE by year
# 2024-07-11 19:03:45,057, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-07-11 19:03:45,057, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-07-11 19:03:45,059, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:45,059, data_manager.py, 108, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:45,250, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-07-11 19:03:45,250, data_manager.py, 82, INFO, Saving data for AAL by year
# 2024-07-11 19:03:46,156, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-07-11 19:03:46,156, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-07-11 19:03:46,158, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:46,158, data_manager.py, 108, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:46,458, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-07-11 19:03:46,458, data_manager.py, 82, INFO, Saving data for AEP by year
# 2024-07-11 19:03:47,565, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-07-11 19:03:47,565, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-07-11 19:03:47,567, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:47,567, data_manager.py, 108, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:47,879, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-07-11 19:03:47,879, data_manager.py, 82, INFO, Saving data for AXP by year
# 2024-07-11 19:03:49,004, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-07-11 19:03:49,004, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-07-11 19:03:49,006, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:49,006, data_manager.py, 108, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:49,300, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-07-11 19:03:49,300, data_manager.py, 82, INFO, Saving data for AIG by year
# 2024-07-11 19:03:50,400, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-07-11 19:03:50,400, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-07-11 19:03:50,402, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:50,402, data_manager.py, 108, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:50,620, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-07-11 19:03:50,620, data_manager.py, 82, INFO, Saving data for AMT by year
# 2024-07-11 19:03:51,734, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-07-11 19:03:51,734, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-07-11 19:03:51,736, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:51,736, data_manager.py, 108, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:51,915, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-07-11 19:03:51,915, data_manager.py, 82, INFO, Saving data for AWK by year
# 2024-07-11 19:03:52,678, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-07-11 19:03:52,678, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-07-11 19:03:52,679, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:52,679, data_manager.py, 108, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:52,916, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-07-11 19:03:52,916, data_manager.py, 82, INFO, Saving data for AMP by year
# 2024-07-11 19:03:53,840, data_manager.py, 73, INFO, Processing ticker AME
# 2024-07-11 19:03:53,840, data_manager.py, 73, INFO, Processing ticker AME
# 2024-07-11 19:03:53,842, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:53,842, data_manager.py, 108, INFO, Getting stock price data for AME from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:54,159, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-07-11 19:03:54,159, data_manager.py, 82, INFO, Saving data for AME by year
# 2024-07-11 19:03:55,780, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-07-11 19:03:55,780, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-07-11 19:03:55,781, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:55,781, data_manager.py, 108, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:56,038, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-07-11 19:03:56,038, data_manager.py, 82, INFO, Saving data for AMGN by year
# 2024-07-11 19:03:57,304, data_manager.py, 73, INFO, Processing ticker APH
# 2024-07-11 19:03:57,304, data_manager.py, 73, INFO, Processing ticker APH
# 2024-07-11 19:03:57,306, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:57,306, data_manager.py, 108, INFO, Getting stock price data for APH from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:57,590, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-07-11 19:03:57,590, data_manager.py, 82, INFO, Saving data for APH by year
# 2024-07-11 19:03:58,767, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-07-11 19:03:58,767, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-07-11 19:03:58,769, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-07-11
# 2024-07-11 19:03:58,769, data_manager.py, 108, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:03:59,020, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-07-11 19:03:59,020, data_manager.py, 82, INFO, Saving data for ADI by year
# 2024-07-11 19:04:00,143, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-07-11 19:04:00,143, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-07-11 19:04:00,144, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:00,144, data_manager.py, 108, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:00,400, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-07-11 19:04:00,400, data_manager.py, 82, INFO, Saving data for ANSS by year
# 2024-07-11 19:04:01,542, data_manager.py, 73, INFO, Processing ticker AON
# 2024-07-11 19:04:01,542, data_manager.py, 73, INFO, Processing ticker AON
# 2024-07-11 19:04:01,544, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:01,544, data_manager.py, 108, INFO, Getting stock price data for AON from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:01,813, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-07-11 19:04:01,813, data_manager.py, 82, INFO, Saving data for AON by year
# 2024-07-11 19:04:02,923, data_manager.py, 73, INFO, Processing ticker APA
# 2024-07-11 19:04:02,923, data_manager.py, 73, INFO, Processing ticker APA
# 2024-07-11 19:04:02,925, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:02,925, data_manager.py, 108, INFO, Getting stock price data for APA from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:03,301, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-07-11 19:04:03,301, data_manager.py, 82, INFO, Saving data for APA by year
# 2024-07-11 19:04:04,444, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-07-11 19:04:04,444, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-07-11 19:04:04,446, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:04,446, data_manager.py, 108, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:04,747, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-07-11 19:04:04,747, data_manager.py, 82, INFO, Saving data for AAPL by year
# 2024-07-11 19:04:05,884, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-07-11 19:04:05,884, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-07-11 19:04:05,885, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:05,885, data_manager.py, 108, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:06,151, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-07-11 19:04:06,151, data_manager.py, 82, INFO, Saving data for AMAT by year
# 2024-07-11 19:04:07,305, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-07-11 19:04:07,305, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-07-11 19:04:07,306, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:07,306, data_manager.py, 108, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:07,516, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-07-11 19:04:07,516, data_manager.py, 82, INFO, Saving data for APTV by year
# 2024-07-11 19:04:08,162, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-07-11 19:04:08,162, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-07-11 19:04:08,164, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:08,164, data_manager.py, 108, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:08,368, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-07-11 19:04:08,368, data_manager.py, 82, INFO, Saving data for ACGL by year
# 2024-07-11 19:04:09,485, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-07-11 19:04:09,485, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-07-11 19:04:09,487, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:09,487, data_manager.py, 108, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:09,793, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-07-11 19:04:09,793, data_manager.py, 82, INFO, Saving data for ADM by year
# 2024-07-11 19:04:10,931, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-07-11 19:04:10,931, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-07-11 19:04:10,933, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:10,933, data_manager.py, 108, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:11,078, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-07-11 19:04:11,078, data_manager.py, 82, INFO, Saving data for ANET by year
# 2024-07-11 19:04:11,571, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-07-11 19:04:11,571, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-07-11 19:04:11,573, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:11,573, data_manager.py, 108, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:11,887, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-07-11 19:04:11,887, data_manager.py, 82, INFO, Saving data for AJG by year
# 2024-07-11 19:04:13,189, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-07-11 19:04:13,189, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-07-11 19:04:13,190, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:13,190, data_manager.py, 108, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:13,422, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-07-11 19:04:13,422, data_manager.py, 82, INFO, Saving data for AIZ by year
# 2024-07-11 19:04:14,378, data_manager.py, 73, INFO, Processing ticker T
# 2024-07-11 19:04:14,378, data_manager.py, 73, INFO, Processing ticker T
# 2024-07-11 19:04:14,380, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:14,380, data_manager.py, 108, INFO, Getting stock price data for T from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:14,686, data_manager.py, 82, INFO, Saving data for T by year
# 2024-07-11 19:04:14,686, data_manager.py, 82, INFO, Saving data for T by year
# 2024-07-11 19:04:15,826, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-07-11 19:04:15,826, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-07-11 19:04:15,828, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:15,828, data_manager.py, 108, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:16,101, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-07-11 19:04:16,101, data_manager.py, 82, INFO, Saving data for ATO by year
# 2024-07-11 19:04:17,214, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-07-11 19:04:17,214, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-07-11 19:04:17,215, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:17,215, data_manager.py, 108, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:17,475, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-07-11 19:04:17,475, data_manager.py, 82, INFO, Saving data for ADSK by year
# 2024-07-11 19:04:18,585, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-07-11 19:04:18,585, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-07-11 19:04:18,587, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:18,587, data_manager.py, 108, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:18,908, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-07-11 19:04:18,908, data_manager.py, 82, INFO, Saving data for ADP by year
# 2024-07-11 19:04:20,100, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-07-11 19:04:20,100, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-07-11 19:04:20,101, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:20,101, data_manager.py, 108, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:20,294, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-07-11 19:04:20,294, data_manager.py, 82, INFO, Saving data for AZO by year
# 2024-07-11 19:04:21,467, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-07-11 19:04:21,467, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-07-11 19:04:21,468, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:21,468, data_manager.py, 108, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:21,727, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-07-11 19:04:21,727, data_manager.py, 82, INFO, Saving data for AVB by year
# 2024-07-11 19:04:22,844, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-07-11 19:04:22,844, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-07-11 19:04:22,845, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:22,845, data_manager.py, 108, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:23,204, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-07-11 19:04:23,204, data_manager.py, 82, INFO, Saving data for AVY by year
# 2024-07-11 19:04:24,398, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-07-11 19:04:24,398, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-07-11 19:04:24,400, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:24,400, data_manager.py, 108, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:24,615, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-07-11 19:04:24,615, data_manager.py, 82, INFO, Saving data for AXON by year
# 2024-07-11 19:04:25,812, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-07-11 19:04:25,812, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-07-11 19:04:25,814, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:25,814, data_manager.py, 108, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:26,066, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-07-11 19:04:26,066, data_manager.py, 82, INFO, Saving data for BKR by year
# 2024-07-11 19:04:27,320, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-07-11 19:04:27,320, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-07-11 19:04:27,321, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:27,321, data_manager.py, 108, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:27,827, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-07-11 19:04:27,827, data_manager.py, 82, INFO, Saving data for BALL by year
# 2024-07-11 19:04:29,088, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-07-11 19:04:29,088, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-07-11 19:04:29,090, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:29,090, data_manager.py, 108, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:29,495, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-07-11 19:04:29,495, data_manager.py, 82, INFO, Saving data for BAC by year
# 2024-07-11 19:04:30,732, data_manager.py, 73, INFO, Processing ticker BK
# 2024-07-11 19:04:30,732, data_manager.py, 73, INFO, Processing ticker BK
# 2024-07-11 19:04:30,734, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:30,734, data_manager.py, 108, INFO, Getting stock price data for BK from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:31,183, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-07-11 19:04:31,183, data_manager.py, 82, INFO, Saving data for BK by year
# 2024-07-11 19:04:32,371, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-07-11 19:04:32,371, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-07-11 19:04:32,372, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:32,372, data_manager.py, 108, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:32,710, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-07-11 19:04:32,710, data_manager.py, 82, INFO, Saving data for BBWI by year
# 2024-07-11 19:04:33,872, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-07-11 19:04:33,872, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-07-11 19:04:33,878, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:33,878, data_manager.py, 108, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:34,206, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-07-11 19:04:34,206, data_manager.py, 82, INFO, Saving data for BAX by year
# 2024-07-11 19:04:35,372, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-07-11 19:04:35,372, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-07-11 19:04:35,377, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:35,377, data_manager.py, 108, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:35,742, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-07-11 19:04:35,742, data_manager.py, 82, INFO, Saving data for BDX by year
# 2024-07-11 19:04:37,029, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-07-11 19:04:37,029, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-07-11 19:04:37,030, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:37,030, data_manager.py, 108, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 2024-07-11 19:04:38,255, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-07-11 19:04:38,255, data_manager.py, 82, INFO, Saving data for BRK.B by year
# 2024-07-11 19:04:38,256, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-07-11 19:04:38,256, data_manager.py, 100, WARNING, No data found for BRK.B
# 2024-07-11 19:04:38,258, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-07-11 19:04:38,258, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-07-11 19:04:38,260, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:38,260, data_manager.py, 108, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:38,540, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-07-11 19:04:38,540, data_manager.py, 82, INFO, Saving data for BBY by year
# 2024-07-11 19:04:39,655, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-07-11 19:04:39,655, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-07-11 19:04:39,657, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:39,657, data_manager.py, 108, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:39,870, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-07-11 19:04:39,870, data_manager.py, 82, INFO, Saving data for BIO by year
# 2024-07-11 19:04:41,006, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-07-11 19:04:41,006, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-07-11 19:04:41,008, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:41,008, data_manager.py, 108, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:41,278, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-07-11 19:04:41,278, data_manager.py, 82, INFO, Saving data for TECH by year
# 2024-07-11 19:04:42,418, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-07-11 19:04:42,418, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-07-11 19:04:42,419, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:42,419, data_manager.py, 108, INFO, Getting stock price data for BIIB from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:42,691, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-07-11 19:04:42,691, data_manager.py, 82, INFO, Saving data for BIIB by year
# 2024-07-11 19:04:43,801, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-07-11 19:04:43,801, data_manager.py, 73, INFO, Processing ticker BLK
# 2024-07-11 19:04:43,803, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:43,803, data_manager.py, 108, INFO, Getting stock price data for BLK from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:44,048, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-07-11 19:04:44,048, data_manager.py, 82, INFO, Saving data for BLK by year
# 2024-07-11 19:04:45,171, data_manager.py, 73, INFO, Processing ticker BX
# 2024-07-11 19:04:45,171, data_manager.py, 73, INFO, Processing ticker BX
# 2024-07-11 19:04:45,172, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:45,172, data_manager.py, 108, INFO, Getting stock price data for BX from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:45,395, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-07-11 19:04:45,395, data_manager.py, 82, INFO, Saving data for BX by year
# 2024-07-11 19:04:46,250, data_manager.py, 73, INFO, Processing ticker BA
# 2024-07-11 19:04:46,250, data_manager.py, 73, INFO, Processing ticker BA
# 2024-07-11 19:04:46,251, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:46,251, data_manager.py, 108, INFO, Getting stock price data for BA from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:46,536, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-07-11 19:04:46,536, data_manager.py, 82, INFO, Saving data for BA by year
# 2024-07-11 19:04:47,662, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-07-11 19:04:47,662, data_manager.py, 73, INFO, Processing ticker BKNG
# 2024-07-11 19:04:47,664, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:47,664, data_manager.py, 108, INFO, Getting stock price data for BKNG from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:47,894, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-07-11 19:04:47,894, data_manager.py, 82, INFO, Saving data for BKNG by year
# 2024-07-11 19:04:49,007, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-07-11 19:04:49,007, data_manager.py, 73, INFO, Processing ticker BWA
# 2024-07-11 19:04:49,009, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:49,009, data_manager.py, 108, INFO, Getting stock price data for BWA from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:49,485, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-07-11 19:04:49,485, data_manager.py, 82, INFO, Saving data for BWA by year
# 2024-07-11 19:04:50,616, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-07-11 19:04:50,616, data_manager.py, 73, INFO, Processing ticker BXP
# 2024-07-11 19:04:50,617, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:50,617, data_manager.py, 108, INFO, Getting stock price data for BXP from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:50,876, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-07-11 19:04:50,876, data_manager.py, 82, INFO, Saving data for BXP by year
# 2024-07-11 19:04:51,991, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-07-11 19:04:51,991, data_manager.py, 73, INFO, Processing ticker BSX
# 2024-07-11 19:04:51,993, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:51,993, data_manager.py, 108, INFO, Getting stock price data for BSX from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:52,207, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-07-11 19:04:52,207, data_manager.py, 82, INFO, Saving data for BSX by year
# 2024-07-11 19:04:53,321, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-07-11 19:04:53,321, data_manager.py, 73, INFO, Processing ticker BMY
# 2024-07-11 19:04:53,322, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:53,322, data_manager.py, 108, INFO, Getting stock price data for BMY from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:53,668, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-07-11 19:04:53,668, data_manager.py, 82, INFO, Saving data for BMY by year
# 2024-07-11 19:04:54,824, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-07-11 19:04:54,824, data_manager.py, 73, INFO, Processing ticker AVGO
# 2024-07-11 19:04:54,826, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:54,826, data_manager.py, 108, INFO, Getting stock price data for AVGO from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:55,047, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-07-11 19:04:55,047, data_manager.py, 82, INFO, Saving data for AVGO by year
# 2024-07-11 19:04:55,771, data_manager.py, 73, INFO, Processing ticker BR
# 2024-07-11 19:04:55,771, data_manager.py, 73, INFO, Processing ticker BR
# 2024-07-11 19:04:55,772, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-07-11
# 2024-07-11 19:04:55,772, data_manager.py, 108, INFO, Getting stock price data for BR from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:04:55,979, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-07-11 19:04:55,979, data_manager.py, 82, INFO, Saving data for BR by year
# 2024-07-11 19:04:56,807, data_manager.py, 73, INFO, Processing ticker BRO
# 2024-07-11 19:04:56,807, data_manager.py, 73, INFO, Processing ticker BRO
# ...
# 2024-07-11 19:13:46,977, data_manager.py, 82, INFO, Saving data for WRB by year
# 2024-07-11 19:13:48,245, data_manager.py, 73, INFO, Processing ticker WAB
# 2024-07-11 19:13:48,245, data_manager.py, 73, INFO, Processing ticker WAB
# 2024-07-11 19:13:48,247, data_manager.py, 108, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-07-11
# 2024-07-11 19:13:48,247, data_manager.py, 108, INFO, Getting stock price data for WAB from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:13:48,616, data_manager.py, 82, INFO, Saving data for WAB by year
# 2024-07-11 19:13:48,616, data_manager.py, 82, INFO, Saving data for WAB by year
# 2024-07-11 19:13:49,915, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-07-11 19:13:49,915, data_manager.py, 73, INFO, Processing ticker WBA
# 2024-07-11 19:13:49,917, data_manager.py, 108, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-07-11
# 2024-07-11 19:13:49,917, data_manager.py, 108, INFO, Getting stock price data for WBA from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:13:50,267, data_manager.py, 82, INFO, Saving data for WBA by year
# 2024-07-11 19:13:50,267, data_manager.py, 82, INFO, Saving data for WBA by year
# 2024-07-11 19:13:51,481, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-07-11 19:13:51,481, data_manager.py, 73, INFO, Processing ticker WMT
# 2024-07-11 19:13:51,482, data_manager.py, 108, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-07-11
# 2024-07-11 19:13:51,482, data_manager.py, 108, INFO, Getting stock price data for WMT from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:13:51,902, data_manager.py, 82, INFO, Saving data for WMT by year
# 2024-07-11 19:13:51,902, data_manager.py, 82, INFO, Saving data for WMT by year
# 2024-07-11 19:13:53,028, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-07-11 19:13:53,028, data_manager.py, 73, INFO, Processing ticker DIS
# 2024-07-11 19:13:53,029, data_manager.py, 108, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-07-11
# 2024-07-11 19:13:53,029, data_manager.py, 108, INFO, Getting stock price data for DIS from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:13:53,438, data_manager.py, 82, INFO, Saving data for DIS by year
# 2024-07-11 19:13:53,438, data_manager.py, 82, INFO, Saving data for DIS by year
# 2024-07-11 19:13:54,624, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-07-11 19:13:54,624, data_manager.py, 73, INFO, Processing ticker WBD
# 2024-07-11 19:13:54,626, data_manager.py, 108, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-07-11
# 2024-07-11 19:13:54,626, data_manager.py, 108, INFO, Getting stock price data for WBD from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:13:54,869, data_manager.py, 82, INFO, Saving data for WBD by year
# 2024-07-11 19:13:54,869, data_manager.py, 82, INFO, Saving data for WBD by year
# 2024-07-11 19:13:55,763, data_manager.py, 73, INFO, Processing ticker WM
# 2024-07-11 19:13:55,763, data_manager.py, 73, INFO, Processing ticker WM
# 2024-07-11 19:13:55,764, data_manager.py, 108, INFO, Getting stock price data for WM from 2000-01-01 to 2024-07-11
# 2024-07-11 19:13:55,764, data_manager.py, 108, INFO, Getting stock price data for WM from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:13:56,073, data_manager.py, 82, INFO, Saving data for WM by year
# 2024-07-11 19:13:56,073, data_manager.py, 82, INFO, Saving data for WM by year
# 2024-07-11 19:13:57,194, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-07-11 19:13:57,194, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-07-11 19:13:57,195, data_manager.py, 108, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-07-11
# 2024-07-11 19:13:57,195, data_manager.py, 108, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:13:57,468, data_manager.py, 82, INFO, Saving data for WAT by year
# 2024-07-11 19:13:57,468, data_manager.py, 82, INFO, Saving data for WAT by year
# 2024-07-11 19:13:58,648, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-07-11 19:13:58,648, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-07-11 19:13:58,649, data_manager.py, 108, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-07-11
# 2024-07-11 19:13:58,649, data_manager.py, 108, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:13:59,036, data_manager.py, 82, INFO, Saving data for WEC by year
# 2024-07-11 19:13:59,036, data_manager.py, 82, INFO, Saving data for WEC by year
# 2024-07-11 19:14:00,174, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-07-11 19:14:00,174, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-07-11 19:14:00,176, data_manager.py, 108, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:00,176, data_manager.py, 108, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:00,679, data_manager.py, 82, INFO, Saving data for WFC by year
# 2024-07-11 19:14:00,679, data_manager.py, 82, INFO, Saving data for WFC by year
# 2024-07-11 19:14:01,847, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-07-11 19:14:01,847, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-07-11 19:14:01,849, data_manager.py, 108, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:01,849, data_manager.py, 108, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:02,190, data_manager.py, 82, INFO, Saving data for WELL by year
# 2024-07-11 19:14:02,190, data_manager.py, 82, INFO, Saving data for WELL by year
# 2024-07-11 19:14:03,500, data_manager.py, 73, INFO, Processing ticker WST
# 2024-07-11 19:14:03,500, data_manager.py, 73, INFO, Processing ticker WST
# 2024-07-11 19:14:03,502, data_manager.py, 108, INFO, Getting stock price data for WST from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:03,502, data_manager.py, 108, INFO, Getting stock price data for WST from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:03,879, data_manager.py, 82, INFO, Saving data for WST by year
# 2024-07-11 19:14:03,879, data_manager.py, 82, INFO, Saving data for WST by year
# 2024-07-11 19:14:05,003, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-07-11 19:14:05,003, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-07-11 19:14:05,005, data_manager.py, 108, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:05,005, data_manager.py, 108, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:05,228, data_manager.py, 82, INFO, Saving data for WDC by year
# 2024-07-11 19:14:05,228, data_manager.py, 82, INFO, Saving data for WDC by year
# 2024-07-11 19:14:06,373, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-07-11 19:14:06,373, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-07-11 19:14:06,375, data_manager.py, 108, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:06,375, data_manager.py, 108, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:06,659, data_manager.py, 82, INFO, Saving data for WRK by year
# 2024-07-11 19:14:06,659, data_manager.py, 82, INFO, Saving data for WRK by year
# 2024-07-11 19:14:07,113, data_manager.py, 73, INFO, Processing ticker WY
# 2024-07-11 19:14:07,113, data_manager.py, 73, INFO, Processing ticker WY
# 2024-07-11 19:14:07,114, data_manager.py, 108, INFO, Getting stock price data for WY from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:07,114, data_manager.py, 108, INFO, Getting stock price data for WY from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:07,500, data_manager.py, 82, INFO, Saving data for WY by year
# 2024-07-11 19:14:07,500, data_manager.py, 82, INFO, Saving data for WY by year
# 2024-07-11 19:14:08,620, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-07-11 19:14:08,620, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-07-11 19:14:08,622, data_manager.py, 108, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:08,622, data_manager.py, 108, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:08,992, data_manager.py, 82, INFO, Saving data for WHR by year
# 2024-07-11 19:14:08,992, data_manager.py, 82, INFO, Saving data for WHR by year
# 2024-07-11 19:14:10,168, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-07-11 19:14:10,168, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-07-11 19:14:10,169, data_manager.py, 108, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:10,169, data_manager.py, 108, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:10,649, data_manager.py, 82, INFO, Saving data for WMB by year
# 2024-07-11 19:14:10,649, data_manager.py, 82, INFO, Saving data for WMB by year
# 2024-07-11 19:14:11,779, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-07-11 19:14:11,779, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-07-11 19:14:11,780, data_manager.py, 108, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:11,780, data_manager.py, 108, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:12,251, data_manager.py, 82, INFO, Saving data for WTW by year
# 2024-07-11 19:14:12,251, data_manager.py, 82, INFO, Saving data for WTW by year
# 2024-07-11 19:14:13,337, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-07-11 19:14:13,337, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-07-11 19:14:13,339, data_manager.py, 108, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:13,339, data_manager.py, 108, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:13,727, data_manager.py, 82, INFO, Saving data for GWW by year
# 2024-07-11 19:14:13,727, data_manager.py, 82, INFO, Saving data for GWW by year
# 2024-07-11 19:14:15,024, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-07-11 19:14:15,024, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-07-11 19:14:15,026, data_manager.py, 108, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:15,026, data_manager.py, 108, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:15,375, data_manager.py, 82, INFO, Saving data for WYNN by year
# 2024-07-11 19:14:15,375, data_manager.py, 82, INFO, Saving data for WYNN by year
# 2024-07-11 19:14:16,414, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-07-11 19:14:16,414, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-07-11 19:14:16,415, data_manager.py, 108, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:16,415, data_manager.py, 108, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:16,838, data_manager.py, 82, INFO, Saving data for XEL by year
# 2024-07-11 19:14:16,838, data_manager.py, 82, INFO, Saving data for XEL by year
# 2024-07-11 19:14:18,134, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-07-11 19:14:18,134, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-07-11 19:14:18,136, data_manager.py, 108, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:18,136, data_manager.py, 108, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:18,426, data_manager.py, 82, INFO, Saving data for XYL by year
# 2024-07-11 19:14:18,426, data_manager.py, 82, INFO, Saving data for XYL by year
# 2024-07-11 19:14:19,114, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-07-11 19:14:19,114, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-07-11 19:14:19,116, data_manager.py, 108, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:19,116, data_manager.py, 108, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:19,463, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-07-11 19:14:19,463, data_manager.py, 82, INFO, Saving data for YUM by year
# 2024-07-11 19:14:20,739, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-07-11 19:14:20,739, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-07-11 19:14:20,740, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:20,740, data_manager.py, 108, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:21,032, data_manager.py, 82, INFO, Saving data for ZBRA by year
# 2024-07-11 19:14:21,032, data_manager.py, 82, INFO, Saving data for ZBRA by year
# 2024-07-11 19:14:22,358, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-07-11 19:14:22,358, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-07-11 19:14:22,360, data_manager.py, 108, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:22,360, data_manager.py, 108, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:22,672, data_manager.py, 82, INFO, Saving data for ZBH by year
# 2024-07-11 19:14:22,672, data_manager.py, 82, INFO, Saving data for ZBH by year
# 2024-07-11 19:14:23,984, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-07-11 19:14:23,984, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-07-11 19:14:23,985, data_manager.py, 108, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:23,985, data_manager.py, 108, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:24,376, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-07-11 19:14:24,376, data_manager.py, 82, INFO, Saving data for ZION by year
# 2024-07-11 19:14:25,703, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-07-11 19:14:25,703, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-07-11 19:14:25,705, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-07-11
# 2024-07-11 19:14:25,705, data_manager.py, 108, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-07-11
# [*********************100%%**********************]  1 of 1 completed
# 2024-07-11 19:14:25,980, data_manager.py, 82, INFO, Saving data for ZTS by year
# 2024-07-11 19:14:25,980, data_manager.py, 82, INFO, Saving data for ZTS by year

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-07-11 19:14:35,504, data_manager.py, 117, INFO, Creating features data.
# 2024-07-11 19:14:35,504, data_manager.py, 117, INFO, Creating features data.
# 2024-07-11 19:14:35,505, data_manager.py, 128, INFO, Loading price data from ../../05_src/data/prices/
# 2024-07-11 19:14:35,505, data_manager.py, 128, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\ShwetankPC\anaconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-07-11 19:14:39,324, data_manager.py, 136, INFO, Creating features
# 2024-07-11 19:14:39,324, data_manager.py, 136, INFO, Creating features
# c:\Documents\DSI ML Certificate\Lesson_6_Production\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:138: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-07-11 19:14:39,402, data_manager.py, 154, INFO, Creating target
# 2024-07-11 19:14:39,402, data_manager.py, 154, INFO, Creating target
# c:\Documents\DSI ML Certificate\Lesson_6_Production\scaling_to_production\01_materials\labs\../../05_src\data_manager.py:155: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-07-11 19:14:39,461, data_manager.py, 164, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-07-11 19:14:39,461, data_manager.py, 164, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
